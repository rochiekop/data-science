# %% [markdown]
# # **Pertemuan #9 - Pandas Data Structure**
#
# Data Wrangling - Sekolah Data - Pacmann Academy

# %% [markdown]
# **Outline**
#
# 1. Review Topik
# 2. Study case 1: Mengolah nilai mahasiswa
# 2. Study case 2: Data pelanggan mall
# 2. Study case 3: Menggabungkan data pasien rumah sakit dari file berbeda
# 2. Study case 4: Mengakses data dari database

# %% [markdown]
# Hal-hal yang harus disiapkan sebelum menggunakan notebook ini.
# - Upload file csv pada workspace yang dibutuhkan untuk notebook ini:
#   - Mall_customer.csv
#   - patient_A1.csv
#   - patient_A2.csv
#   - patient.xlsx
#   - chinook.db
# - import library pandas, yaitu library yang akan digunakan dalam notebook ini.

# %%
# import pandas 
import pandas as pd

# %% [markdown]
# ## **Review Topik**
# ---
#
# Dari materi yang sudah dipelajari di video:

# %% [markdown]
# ### **Pandas dan Data Structure**
#
# - Pandas package
# - Series
# - DataFrame

# %% [markdown]
# ### **Membaca Data**
#
# - Read data menggunakan fungsi read_csv()
# - Parameter pada read_csv()
# - Fungsi untuk membaca file data lain seperti sql, excel, stata

# %% [markdown]
# ### **Casting type data**
#
# - Mengubah type data pada series atau dataframe

# %% [markdown]
# ### **Mengombinasikan data**
#
# - Menggabung data menggunakan fungsi concat()
# - Menggabung data menggunakan fungsi merge()
# - Menggabung data menggunakan fungsi join()

# %% [markdown]
# ### **Mengoksport data**
#
# - Mengeksport dataframe menjadi file

# %% [markdown]
# ## **Study Case 1: Mengolah nilai mahasiswa**
# ___
#
# Anda mendapat tugas untuk mengolah data nilai mahasiswa di bawah ini.
#
# |Nama|Nilai|
# |-|-|
# |Juchiro|83.54|
# |Fandy|86.79|
# |Erlangga|88.57|
# |Matheos|71.48|
# |Sugeng|72.65|
# |Atma|92.73|
# |Muliana|83.22|
# |Iyya|77.72|
# |Budiarto|85.09|
# |Afendy|88.98|
# |Muhaimin|68.40|

# %% [markdown]
# ### 1.1
# Buat series dari nilai tersebut. Nama sebagai index, nilai sebagai value

# %%
# buat data nilai dalam bentuk python dictionary
data_nilai = {
    "Juchiro": 83.54,
    "Fandy":86.79,
    "Erlangga":88.57,
    "Matheos":71.48,
    "Sugeng":72.65,
    "Atma":92.73,
    "Muliana":83.22,
    "Iyya":77.72,
    "Budiarto":85.09,
    "Afendy":88.98,
    "Muhaimin":68.40,
}

# buat series dari data dictionary
data = pd.Series(data_nilai)

# tampilkan data
data
# Out:
# Juchiro     83.54
# Fandy       86.79
# Erlangga    88.57
# Matheos     71.48
# Sugeng      72.65
# Atma        92.73
# Muliana     83.22
# Iyya        77.72
# Budiarto    85.09
# Afendy      88.98
# Muhaimin    68.40
# dtype: float64

# %% [markdown]
# ### 1.2
# Tampilkan nilai Fandy dan Atma secara terpisah. Serta Tampilkan nilai Erlangga, Budiarto, dan Muhaimin bersamaan.

# %%
print('Nilai Fandy : ',data['Fandy'])
print('Nilai Atma : ',data['Atma'])
data[["Erlangga", "Budiarto", "Muhaimin"]]
# Out:
# Nilai Fandy :  86.79
# Nilai Atma :  92.73
# Erlangga    88.57
# Budiarto    85.09
# Muhaimin    68.40
# dtype: float64

# %% [markdown]
# ### 1.3
# Tambahkan data berikut pada series yang telah dibuat
#
# |Nama|Nilai|
# |-|-|
# |Yusril|86.35|
# |Priyo|74.73|
# |Yosua|79.12|

# %%
new_data = {
    "Yusril" : 86.35,
    "Priyo"  : 74.73,
    "Yosua"  : 79.12
}
n_series = pd.Series(new_data)
n_series
# Out:
# Yusril    86.35
# Priyo     74.73
# Yosua     79.12
# dtype: float64

# %%
data = data.append(n_series)
data
# Out:
# Juchiro     83.54
# Fandy       86.79
# Erlangga    88.57
# Matheos     71.48
# Sugeng      72.65
# Atma        92.73
# Muliana     83.22
# Iyya        77.72
# Budiarto    85.09
# Afendy      88.98
# Muhaimin    68.40
# Yusril      86.35
# Priyo       74.73
# Yosua       79.12
# dtype: float64

# %% [markdown]
# ### 1.4
# Ubah nilai mahasiswa berikut ini:
# * Muliana menjadi 92.45
# * Iyya menjadi 79.80
# * Juchiro dan Fandi masing-masing menjadi 90 dan 91 (secara bersamaan)

# %%
data["Muliana"]
# Out:
# 92.45

# %%
data[["Muliana","Iyya","Juchiro","Fandy"]] = [92.45,79.80,90,91]

# %%
data
# Out:
# Juchiro     90.00
# Fandy       91.00
# Erlangga    88.57
# Matheos     71.48
# Sugeng      72.65
# Atma        92.73
# Muliana     92.45
# Iyya        79.80
# Budiarto    85.09
# Afendy      88.98
# Muhaimin    68.40
# Yusril      86.35
# Priyo       74.73
# Yosua       79.12
# dtype: float64

# %% [markdown]
# ### 1.5
# Export data menjadi file csv dengan nama "nilai_mahasiswa_update.csv"

# %%
data.to_csv("nilai_mahasiswa_update.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ### Exercise

# %% [markdown]
# 1. Ubah nilai Afendy dan Sugeng masing-masing menjadi 85.5 dan 77.77
# 2. Ubah data nilai tersebut menjadi rentang nilai 1-10
# 3. Hapus nilai Matheos dan Fandy
# 4. Export data menjadi data excel

# %%
data[["Afendy","Sugeng"]] = [85.5,77.77]
data
# Out:
# Juchiro     90.00
# Fandy       91.00
# Erlangga    88.57
# Matheos     71.48
# Sugeng      77.77
# Atma        92.73
# Muliana     92.45
# Iyya        79.80
# Budiarto    85.09
# Afendy      85.50
# Muhaimin    68.40
# Yusril      86.35
# Priyo       74.73
# Yosua       79.12
# dtype: float64

# %%
data = data/10

# %%
data
# Out:
# Juchiro     9.000
# Fandy       9.100
# Erlangga    8.857
# Matheos     7.148
# Sugeng      7.777
# Atma        9.273
# Muliana     9.245
# Iyya        7.980
# Budiarto    8.509
# Afendy      8.550
# Muhaimin    6.840
# Yusril      8.635
# Priyo       7.473
# Yosua       7.912
# dtype: float64

# %%
data = data.drop(["Matheos","Fandy"])
data
# Out:
# Juchiro     9.000
# Erlangga    8.857
# Sugeng      7.777
# Atma        9.273
# Muliana     9.245
# Iyya        7.980
# Budiarto    8.509
# Afendy      8.550
# Muhaimin    6.840
# Yusril      8.635
# Priyo       7.473
# Yosua       7.912
# dtype: float64

# %%
data=data.round(2)

# %%
data
# Out:
# Juchiro     9.00
# Erlangga    8.86
# Sugeng      7.78
# Atma        9.27
# Muliana     9.25
# Iyya        7.98
# Budiarto    8.51
# Afendy      8.55
# Muhaimin    6.84
# Yusril      8.64
# Priyo       7.47
# Yosua       7.91
# dtype: float64

# %%
data.to_excel("nilai_mahasiswa_new.xlsx")

# %% [markdown]
# ## **Study Case 2:  Data Pelanggan Mall**
# ___
#
# Anda mendapat tugas sebagai admin dalam sebuah mall. Anda mendapat tugas untuk melakukan beberapa perubahan pada data pelanggan mall tersebut. Tapi, data tersebut tersimpan dalam bentuk file csv dengan nama "Mall_Customer.csv".

# %% [markdown]
# ### 2.1
# Buka data file csv tersebut dalam bentuk dataframe.

# %%
# Baca data csv menggunakan fungsi pada pandas.
data = pd.read_csv("Mall_Customers.csv")

# tampilkan data
data
# Out:
#      CustomerID   Genre  Age  Annual_Income_(k$)  Spending_Score
# 0             1    Male   19                  15              39
# 1             2    Male   21                  15              81
# 2             3  Female   20                  16               6
# 3             4  Female   23                  16              77
# 4             5  Female   31                  17              40
# ..          ...     ...  ...                 ...             ...
# 195         196  Female   35                 120              79
# 196         197  Female   45                 126              28
# 197         198    Male   32                 126              74
# 198         199    Male   32                 137              18
# 199         200    Male   30                 137              83
#
# [200 rows x 5 columns]

# %%
data.shape
# Out:
# (200, 5)

# %% [markdown]
# ### 2.2
# Index pada data merupakan angka dari 0 hingga 199. Anda diminta untuk mengubah Index menjadi angka hasil penjumlahan 1000 dengan "CustomerID". Misalnya CustomerID = 9, index menjadi 1009. Kemudian hapus  kolom "CustomerID"

# %%
idx = data["CustomerID"].values + 1000
data.index = idx
data
# Out:
#       CustomerID   Genre  Age  Annual_Income_(k$)  Spending_Score
# 1001           1    Male   19                  15              39
# 1002           2    Male   21                  15              81
# 1003           3  Female   20                  16               6
# 1004           4  Female   23                  16              77
# 1005           5  Female   31                  17              40
# ...          ...     ...  ...                 ...             ...
# 1196         196  Female   35                 120              79
# 1197         197  Female   45                 126              28
# 1198         198    Male   32                 126              74
# 1199         199    Male   32                 137              18
# 1200         200    Male   30                 137              83
#
# [200 rows x 5 columns]

# %%
data
# Out:
#       CustomerID   Genre  Age  Annual_Income_(k$)  Spending_Score
# 1001           1    Male   19                  15              39
# 1002           2    Male   21                  15              81
# 1003           3  Female   20                  16               6
# 1004           4  Female   23                  16              77
# 1005           5  Female   31                  17              40
# ...          ...     ...  ...                 ...             ...
# 1196         196  Female   35                 120              79
# 1197         197  Female   45                 126              28
# 1198         198    Male   32                 126              74
# 1199         199    Male   32                 137              18
# 1200         200    Male   30                 137              83
#
# [200 rows x 5 columns]

# %%
# Drop CustomerId
data.drop("CustomerID",axis=1, inplace=True)
data
# Out:
#        Genre  Age  Annual_Income_(k$)  Spending_Score
# 1001    Male   19                  15              39
# 1002    Male   21                  15              81
# 1003  Female   20                  16               6
# 1004  Female   23                  16              77
# 1005  Female   31                  17              40
# ...      ...  ...                 ...             ...
# 1196  Female   35                 120              79
# 1197  Female   45                 126              28
# 1198    Male   32                 126              74
# 1199    Male   32                 137              18
# 1200    Male   30                 137              83
#
# [200 rows x 4 columns]

# %% [markdown]
# ### 2.3
# Customer 1098 dan 1099 tidak lagi menjadi pelanggan pada mall tersebut.Anda diminta untuk menghapus data index 1098 dan 1099.

# %%
data = data.drop([1098,1099],axis=0)
data
# Out:
#        Genre  Age  Annual_Income_(k$)  Spending_Score
# 1001    Male   19                  15              39
# 1002    Male   21                  15              81
# 1003  Female   20                  16               6
# 1004  Female   23                  16              77
# 1005  Female   31                  17              40
# ...      ...  ...                 ...             ...
# 1196  Female   35                 120              79
# 1197  Female   45                 126              28
# 1198    Male   32                 126              74
# 1199    Male   32                 137              18
# 1200    Male   30                 137              83
#
# [198 rows x 4 columns]

# %% [markdown]
# ### 2.4
# Ada data baru pada data customer. Anda Harus menambahkan data baru berikut.
#
# ||Genre|Age|Annual_Income_(k$)|Spending_Score
# |-|-|-|-|-|
# |1201|Male|22|20|83

# %%
n_df = pd.DataFrame({
    "Genre" : "Male",
    "Age"   : 22,
    "Annual_Income_(k$)":20,
    "Spending_Score":83},
    index=[1201]
)
n_df
# Out:
#      Genre  Age  Annual_Income_(k$)  Spending_Score
# 1201  Male   22                  20              83

# %%
data = data.append(n_df)
data
# Out:
#        Genre  Age  Annual_Income_(k$)  Spending_Score
# 1001    Male   19                  15              39
# 1002    Male   21                  15              81
# 1003  Female   20                  16               6
# 1004  Female   23                  16              77
# 1005  Female   31                  17              40
# ...      ...  ...                 ...             ...
# 1197  Female   45                 126              28
# 1198    Male   32                 126              74
# 1199    Male   32                 137              18
# 1200    Male   30                 137              83
# 1201    Male   22                  20              83
#
# [199 rows x 4 columns]

# %% [markdown]
# ### 2.5
# Data income dan score kedepannya berpotensi berisi data float. Ubah type data income dan score menjadi float.

# %%
data['Annual_Income_(k$)'] = data['Annual_Income_(k$)'].astype(float)
data['Spending_Score'] = data["Spending_Score"].astype(float)
data
# Out:
#        Genre  Age  Annual_Income_(k$)  Spending_Score
# 1001    Male   19                15.0            39.0
# 1002    Male   21                15.0            81.0
# 1003  Female   20                16.0             6.0
# 1004  Female   23                16.0            77.0
# 1005  Female   31                17.0            40.0
# ...      ...  ...                 ...             ...
# 1197  Female   45               126.0            28.0
# 1198    Male   32               126.0            74.0
# 1199    Male   32               137.0            18.0
# 1200    Male   30               137.0            83.0
# 1201    Male   22                20.0            83.0
#
# [199 rows x 4 columns]

# %%
# tampilkan type data tiap kolom
data.dtypes
# Out:
# Genre                  object
# Age                     int64
# Annual_Income_(k$)    float64
# Spending_Score        float64
# dtype: object

# %% [markdown]
# ### Exercise

# %% [markdown]
# 1. Ubah masing-masing header sesuai data berikut:
#   * Genre = JenisKelamin
#   * Age = Umur
#   * Annual_Income_(k$) = Pendapatan
#   * Spending_Score = Skor
# 2. Tambah data berikut:
#
# ||JenisKelamin|Umur|Pendapatan|Skor
# |-|-|-|-|-|
# |1202|Male|23|100.5|50.4
# |1205|Female|45|70.5|35.6
# |1207|Male|35|88.3|54.8
#
# 3. Ubah umur data index 1200 menjadi 31 dan Update data index 1002 menjadi:
#
# ||JenisKelamin|Umur|Pendapatan|Skor
# |-|-|-|-|-|
# |1002|Male|22|20|83
#
# 4. Export data menjadi data excel

# %%
new_header = {
    "Genre":"JenisKelamin",
    "Age":"Umur",
    "Annual_Income_(k$)":"Pendapatan",
    "Spending_Score":"Skor"
}
data = data.rename(columns=new_header)
data
# Out:
#      JenisKelamin  Umur  Pendapatan  Skor
# 1001         Male    19        15.0  39.0
# 1002         Male    21        15.0  81.0
# 1003       Female    20        16.0   6.0
# 1004       Female    23        16.0  77.0
# 1005       Female    31        17.0  40.0
# ...           ...   ...         ...   ...
# 1197       Female    45       126.0  28.0
# 1198         Male    32       126.0  74.0
# 1199         Male    32       137.0  18.0
# 1200         Male    30       137.0  83.0
# 1201         Male    22        20.0  83.0
#
# [199 rows x 4 columns]

# %%
# Add new data
val = {
    "JenisKelamin" : ["Male","Female","Male"],
    "Umur": [23,45,35],
    "Pendapatan":[100.5,70.5,88.3],
    "Skor":[50.4,35.6,54.8]
}
idx = [1202,1205,1207]
n_df = pd.DataFrame(val,index=idx)
n_df
# Out:
#      JenisKelamin  Umur  Pendapatan  Skor
# 1202         Male    23       100.5  50.4
# 1205       Female    45        70.5  35.6
# 1207         Male    35        88.3  54.8

# %%
data = data.append(n_df)
data
# Out:
#      JenisKelamin  Umur  Pendapatan  Skor
# 1001         Male    19        15.0  39.0
# 1002         Male    21        15.0  81.0
# 1003       Female    20        16.0   6.0
# 1004       Female    23        16.0  77.0
# 1005       Female    31        17.0  40.0
# ...           ...   ...         ...   ...
# 1200         Male    30       137.0  83.0
# 1201         Male    22        20.0  83.0
# 1202         Male    23       100.5  50.4
# 1205       Female    45        70.5  35.6
# 1207         Male    35        88.3  54.8
#
# [202 rows x 4 columns]

# %%
data.loc[[1200],["Umur"]]
# Out:
#       Umur
# 1200    31

# %%
# Ubah umur data index 1200 menjadi 31
data.loc[[1200],["Umur"]] = 31
data
# Out:
#      JenisKelamin  Umur  Pendapatan  Skor
# 1001         Male    19        15.0  39.0
# 1002         Male    21        15.0  81.0
# 1003       Female    20        16.0   6.0
# 1004       Female    23        16.0  77.0
# 1005       Female    31        17.0  40.0
# ...           ...   ...         ...   ...
# 1200         Male    31       137.0  83.0
# 1201         Male    22        20.0  83.0
# 1202         Male    23       100.5  50.4
# 1205       Female    45        70.5  35.6
# 1207         Male    35        88.3  54.8
#
# [202 rows x 4 columns]

# %%
# Update data index 1002
data.loc[1002] = ["Male",22,20,83]
data
# Out:
#      JenisKelamin  Umur  Pendapatan  Skor
# 1001         Male    19        15.0  39.0
# 1002         Male    22        20.0  83.0
# 1003       Female    20        16.0   6.0
# 1004       Female    23        16.0  77.0
# 1005       Female    31        17.0  40.0
# ...           ...   ...         ...   ...
# 1200         Male    31       137.0  83.0
# 1201         Male    22        20.0  83.0
# 1202         Male    23       100.5  50.4
# 1205       Female    45        70.5  35.6
# 1207         Male    35        88.3  54.8
#
# [202 rows x 4 columns]

# %%
data.to_excel("mall_customer_edited.xlsx")

# %% [markdown]
# ## Study Case 3: Menggabungkan data pasien rumah sakit dari file berbeda.
# Ada 4 file dari 2 rumah sakit yang berbeda yang harus anda gabung.
# * File "patient_A1.csv" merupakan data pasien dari rumah sakit A yang berisi data Pregnancies, Glucose, BloodPressure, SkinThickness.
# * File "patient_A2.csv" merupakan data pasien dari rumah sakit A yang berisi data Insulin, BMI, Diabetes, PedigreeFunction, Age, Outcome.
# * File "patient.xlsx" merupakan data pasien dari rumah sakit B yang berisi data
#   - sheet patient_B1: IdPatient, Pregnancies, SkinThickness, BMI, Age, Outcome.
#   - sheet patient_B2: IdPatient, Glucose, BloodPressure, DiabetesPedigreeFunction.

# %% [markdown]
# ### 3.1
# Buat dataframe dari setiap file csv yang diberikan.

# %%
# Baca data csv menggunakan fungsi pada pandas.
dataA1 = pd.read_csv("patient_A1.csv")

# tampilkan data
dataA1.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness
# 0            6      148             72             35
# 1            1       85             66             29
# 2            8      183             64              0
# 3            1       89             66             23
# 4            0      137             40             35

# %%
dataA2 = pd.read_csv("patient_A2.csv")
dataA2.head()
# Out:
#    Insulin   BMI  DiabetesPedigreeFunction  Age  Outcome
# 0        0  33.6                     0.627   50        1
# 1        0  26.6                     0.351   31        0
# 2        0  23.3                     0.672   32        1
# 3       94  28.1                     0.167   21        0
# 4      168  43.1                     2.288   33        1

# %%
dataB1 = pd.read_excel("patient.xlsx",sheet_name="patient_B1")
dataB1.tail()
# Out:
#      IdPatient  Pregnancies  SkinThickness   BMI  Age  Outcome
# 269        369           10             48  32.9   63        0
# 270        370            2             27  36.8   27        0
# 271        371            5             23  26.2   30        0
# 272        372            1              0  30.1   47        1
# 273        373            1             31  30.4   23        0

# %%
dataB2 = pd.read_excel("patient.xlsx",sheet_name="patient_B2")
dataB2.tail()
# Out:
#      IdPatient  Glucose  BloodPressure  DiabetesPedigreeFunction
# 269        369      101             76                     0.171
# 270        370      122             70                     0.340
# 271        371      121             72                     0.245
# 272        372      126             60                     0.349
# 273        373       93             70                     0.315

# %% [markdown]
# ### 3.2
# Anda harus menggabungkan 4 file tersebut menjadi 1 dataframe.

# %%
dataA = pd.concat([dataA1,dataA2],axis=1)
dataA
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 167            4      120             68              0        0  29.6
# 168            4      110             66              0        0  31.9
# 169            3      111             90             12       78  28.4
# 170            6      102             82              0        0  30.8
# 171            6      134             70             23      130  35.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
dataB = dataB1.merge(dataB2, on="IdPatient")
dataB
# Out:
#      IdPatient  Pregnancies  SkinThickness   BMI  Age  Outcome  Glucose  \
# 0          100            3              0   0.0   22        0       80
# 1          101            6              0  26.6   66        0      166
# 2          102            5              0  26.0   30        0      110
# 3          103            2             15  30.1   25        0       81
# 4          104            7             33  25.1   55        1      195
# ..         ...          ...            ...   ...  ...      ...      ...
# 269        369           10             48  32.9   63        0      101
# 270        370            2             27  36.8   27        0      122
# 271        371            5             23  26.2   30        0      121
# 272        372            1              0  30.1   47        1      126
# 273        373            1             31  30.4   23        0       93
#
#      BloodPressure  DiabetesPedigreeFunction
# 0                0                     0.174
# ...

# %%
# Drop IdPatient
dataB = dataB.drop("IdPatient", axis= 1)
dataB
# Out:
#      Pregnancies  SkinThickness   BMI  Age  Outcome  Glucose  BloodPressure  \
# 0              3              0   0.0   22        0       80              0
# 1              6              0  26.6   66        0      166             74
# 2              5              0  26.0   30        0      110             68
# 3              2             15  30.1   25        0       81             72
# 4              7             33  25.1   55        1      195             70
# ..           ...            ...   ...  ...      ...      ...            ...
# 269           10             48  32.9   63        0      101             76
# 270            2             27  36.8   27        0      122             70
# 271            5             23  26.2   30        0      121             72
# 272            1              0  30.1   47        1      126             60
# 273            1             31  30.4   23        0       93             70
#
#      DiabetesPedigreeFunction
# ...

# %%
# gabungkan data rumah sakit A dan rumah sakit B
data = pd.concat([dataA, dataB], ignore_index=True)

# tampilkan data
data
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#      Age   BMI  BloodPressure  DiabetesPedigreeFunction  Glucose  Insulin  \
# 0     50  33.6             72                     0.627      148      0.0
# 1     31  26.6             66                     0.351       85      0.0
# 2     32  23.3             64                     0.672      183      0.0
# 3     21  28.1             66                     0.167       89     94.0
# 4     33  43.1             40                     2.288      137    168.0
# ..   ...   ...            ...                       ...      ...      ...
# 441   63  32.9             76                     0.171      101      NaN
# ...

# %% [markdown]
# ### 3.3
# Anda diminta menghapus data Pregnancies, DiabetesPedigreeFunction, dan Outcome karena tidak dibutuhkan

# %%
#  hapus data Pregnancies, DiabetesPedigreeFunction, dan Outcome
data = data.drop(["Pregnancies","DiabetesPedigreeFunction","Outcome"], axis=1)
data
# Out:
#      Age   BMI  BloodPressure  Glucose  Insulin  SkinThickness
# 0     50  33.6             72      148      0.0             35
# 1     31  26.6             66       85      0.0             29
# 2     32  23.3             64      183      0.0              0
# 3     21  28.1             66       89     94.0             23
# 4     33  43.1             40      137    168.0             35
# ..   ...   ...            ...      ...      ...            ...
# 441   63  32.9             76      101      NaN             48
# 442   27  36.8             70      122      NaN             27
# 443   30  26.2             72      121      NaN             23
# 444   47  30.1             60      126      NaN              0
# 445   23  30.4             70       93      NaN             31
#
# [446 rows x 6 columns]

# %% [markdown]
# ### 3.4
# Anda diminta untuk menampilkan 10 data pertama untuk data Glucose, BloodPressure, dan Age.

# %%
data[["Glucose","BloodPressure","Age"]].head(10)
# Out:
#    Glucose  BloodPressure  Age
# 0      148             72   50
# 1       85             66   31
# 2      183             64   32
# 3       89             66   21
# 4      137             40   33
# 5      116             74   30
# 6       78             50   26
# 7      115              0   29
# 8      197             70   53
# 9      125             96   54

# %%
data.loc[data.head(10).index,["Glucose","BloodPressure","Age"]]
# Out:
#    Glucose  BloodPressure  Age
# 0      148             72   50
# 1       85             66   31
# 2      183             64   32
# 3       89             66   21
# 4      137             40   33
# 5      116             74   30
# 6       78             50   26
# 7      115              0   29
# 8      197             70   53
# 9      125             96   54

# %%
df_back = data
df_back
# Out:
#      Age   BMI  BloodPressure  Glucose  Insulin  SkinThickness
# 0     50  33.6             72      148      0.0             35
# 1     31  26.6             66       85      0.0             29
# 2     32  23.3             64      183      0.0              0
# 3     21  28.1             66       89     94.0             23
# 4     33  43.1             40      137    168.0             35
# ..   ...   ...            ...      ...      ...            ...
# 441   63  32.9             76      101      NaN             48
# 442   27  36.8             70      122      NaN             27
# 443   30  26.2             72      121      NaN             23
# 444   47  30.1             60      126      NaN              0
# 445   23  30.4             70       93      NaN             31
#
# [446 rows x 6 columns]

# %% [markdown]
# ### Exercise

# %% [markdown]
# 1. Tampilkan data pada urutan ke 100 hingga 107 untuk data Insulin dan BMI
# 2. Hapus 5 data terakhir
# 3. Eksport data menjadi 2 file.
#   * File pertama berisi semua data kolom dan export ke file csv
#   * File kedua berisi hanya berisi data BMI dan Age ke file excel.

# %%
data.loc[99:106,["Insulin","BMI"]]
# Out:
#      Insulin   BMI
# 99     220.0  49.7
# 100      0.0  39.0
# 101      0.0  26.1
# 102      0.0  22.5
# 103     40.0  26.6
# 104      0.0  39.6
# 105    152.0  28.7
# 106      0.0  22.4

# %%
data.iloc[99:107, 3:5]

# %%
type(data.tail().index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
data = data.drop(data.tail(5).index)
data.tail()
# Out:
#      Age   BMI  BloodPressure  Glucose  Insulin  SkinThickness
# 436   26  37.5             76      106      NaN              0
# 437   66  35.5             92      190      NaN              0
# 438   22  28.4             58       88      NaN             26
# 439   43  44.0             74      170      NaN             31
# 440   33  22.5             62       89      NaN              0

# %%
data
# Out:
#      Age   BMI  BloodPressure  Glucose  Insulin  SkinThickness
# 0     50  33.6             72      148      0.0             35
# 1     31  26.6             66       85      0.0             29
# 2     32  23.3             64      183      0.0              0
# 3     21  28.1             66       89     94.0             23
# 4     33  43.1             40      137    168.0             35
# ..   ...   ...            ...      ...      ...            ...
# 436   26  37.5             76      106      NaN              0
# 437   66  35.5             92      190      NaN              0
# 438   22  28.4             58       88      NaN             26
# 439   43  44.0             74      170      NaN             31
# 440   33  22.5             62       89      NaN              0
#
# [441 rows x 6 columns]

# %%
# Import to CSV
csv_name = "medical_record_all_column.csv"
data.to_csv(csv_name)

# %%
# Import to CSV
xlsx_name = "medical_record_filtered_column.xlsx"
data[["BMI","Age"]].to_excel(xlsx_name)

# %% [markdown]
# ## Study Case 4 : Akses data aplikasi pemutar musik
#
# Anda diminta untuk mengakses data dari database sebuah aplikasi pemutar musik, `chinook.db`.
#
# ERD dari database tersebut:
#
# <img src="https://www.sqlitetutorial.net/wp-content/uploads/2015/11/sqlite-sample-database-color.jpg" alt="Drawing" width= 620px;/>

# %% [markdown]
# ### 4.1
# Akseslah data invoice dari database tersebut.
#
# Untuk mengakses database menggunakan pandas, dapat mengikuti langkah-langkah berikut:
# 1. Membuat koneksi ke database
# 2. Mengakses database menggunakan `read_sql()` dan memasukkan koneksi dan query sebagai parameter untuk mengakses data dari database

# %%
# Import library untuk membuat koneksi ke database
import sqlite3

# %%
# membuat koneksi ke database chinook.db
con = sqlite3.connect("chinook.db")

# %%
# mengakses data invoice
invoice = pd.read_sql("SELECT * from invoices", con)
invoice
# Out:
#      InvoiceId  CustomerId          InvoiceDate  \
# 0            1           2  2009-01-01 00:00:00
# 1            2           4  2009-01-02 00:00:00
# 2            3           8  2009-01-03 00:00:00
# 3            4          14  2009-01-06 00:00:00
# 4            5          23  2009-01-11 00:00:00
# ..         ...         ...                  ...
# 407        408          25  2013-12-05 00:00:00
# 408        409          29  2013-12-06 00:00:00
# 409        410          35  2013-12-09 00:00:00
# 410        411          44  2013-12-14 00:00:00
# 411        412          58  2013-12-22 00:00:00
#
#                                BillingAddress BillingCity BillingState  \
# 0                     Theodor-Heuss-Straße 34   Stuttgart         None
# 1                            Ullevålsveien 14        Oslo         None
# 2                             Grétrystraat 63    Brussels         None
# 3                              8210 111 ST NW    Edmonton           AB
# ...

# %% [markdown]
# ### 4.2
# Akseslah data customer yang telah memiliki invoice

# %%
# Membuat query
query = """
SELECT * FROM invoices
INNER JOIN customers
ON invoices.CustomerId = customers.CustomerId
"""

# Mengakses customers yang memiliki invoice
customer_w_invoice = pd.read_sql(query, con)
customer_w_invoice
# Out:
#      InvoiceId  CustomerId          InvoiceDate  \
# 0           98           1  2010-03-11 00:00:00
# 1          121           1  2010-06-13 00:00:00
# 2          143           1  2010-09-15 00:00:00
# 3          195           1  2011-05-06 00:00:00
# 4          316           1  2012-10-27 00:00:00
# ..         ...         ...                  ...
# 407         45          59  2009-07-08 00:00:00
# 408         97          59  2010-02-26 00:00:00
# 409        218          59  2011-08-20 00:00:00
# 410        229          59  2011-09-30 00:00:00
# 411        284          59  2012-05-30 00:00:00
#
#                       BillingAddress          BillingCity BillingState  \
# 0    Av. Brigadeiro Faria Lima, 2170  São José dos Campos           SP
# 1    Av. Brigadeiro Faria Lima, 2170  São José dos Campos           SP
# 2    Av. Brigadeiro Faria Lima, 2170  São José dos Campos           SP
# 3    Av. Brigadeiro Faria Lima, 2170  São José dos Campos           SP
# ...
